# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Pulkit\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Loading YOLOv8 model
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:02<00:00, 3.17MB/s]

# %%
# Prediction on image
results = model.predict('busy_street.jpg')
# Out:
# image 1/1 C:\Users\Pulkit\Desktop\YOLO_Project\busy_street.jpg: 384x640 12 persons, 8 cars, 1 motorcycle, 1 bus, 2 traffic lights, 107.1ms
# Speed: 8.6ms preprocess, 107.1ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Displaying result
result = results[0]

img_with_boxes = result.plot()

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)) 
plt.title("YOLOv8 Detection Results")
plt.axis('off') 
plt.show()

# %%
# Prediction on image
result2 = model.predict('market_scene.jpg')
# Out:
# image 1/1 C:\Users\Pulkit\Desktop\YOLO_Project\market_scene.jpg: 512x640 8 persons, 1 handbag, 1 bowl, 136.6ms
# Speed: 2.0ms preprocess, 136.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)

# %%
# Displaying result
result = result2[0]

img_with_boxes = result.plot()

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)) 
plt.title("YOLOv8 Detection Results")
plt.axis('off') 
plt.show()

# %%
#Your path
image_path = ''
results = model.predict(image_path)

result = result2[0]

img_with_boxes = result.plot()

plt.figure(figsize=(12, 12))
plt.imshow(cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)) 
plt.title("YOLOv8 Detection Results")
plt.axis('off') 
plt.show()
